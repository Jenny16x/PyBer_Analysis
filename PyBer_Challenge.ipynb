# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "city_data.csv"
ride_data_to_load = "ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
total_rides_by_type = pyber_data_df.groupby(["type"]).count()['ride_id']

# %%
total_driver_by_type = pyber_data_df.groupby(["type"]).sum()['driver_count']

# %%
urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
urban_cities_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 1620        Reynoldsfurt  2019-02-14 11:25:10  39.40  9070692324754
# 1621     Christopherfurt  2019-03-13 01:47:52  32.05  2788817929605
# 1622        Raymondhaven  2019-03-20 02:20:34  38.53  8658255136559
# 1623       Port Johnbury  2019-03-26 07:22:45   7.63  8089282605778
# 1624        West Gabriel  2019-05-05 01:24:06  27.57  4428773411209
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
suburban_cities_df
# Out:
#                  city                 date   fare        ride_id  \
# 1625    Barronchester  2019-01-27 03:08:01  27.79  6653622887913
# 1626    East Kentstad  2019-04-07 19:44:19  18.75  6575961095852
# 1627        Lake Omar  2019-01-17 21:33:35  21.71   966911700371
# 1628       Myersshire  2019-02-27 17:38:39  17.10  5706770909868
# 1629      West Hannah  2019-04-19 01:06:59  37.78  2273047151891
# ...               ...                  ...    ...            ...
# 2245      West Hannah  2019-03-02 17:06:03  13.92  7388937249208
# 2246  Lake Robertside  2019-04-03 03:27:45  12.76  1301757653884
# 2247      Colemanland  2019-01-10 06:49:58  27.70  8704067171414
# 2248   East Marymouth  2019-02-12 23:18:53  47.41  7409660239158
# 2249      New Raymond  2019-02-11 17:28:27  17.97  7551674475043
#
#       driver_count      type
# 1625            11  Suburban
# 1626            20  Suburban
# 1627            22  Suburban
# 1628            19  Suburban
# 1629            12  Suburban
# ...

# %%
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]
rural_cities_df
# Out:
#                  city                 date   fare        ride_id  \
# 2250   Randallchester  2019-04-13 11:13:31  43.22  1076079536213
# 2251      North Holly  2019-02-02 14:54:00  12.42  1985256326182
# 2252      Michaelberg  2019-03-27 18:27:34  54.85  4421836952718
# 2253  Lake Latoyabury  2019-02-23 21:12:24  47.90  3269652929887
# 2254  Lake Latoyabury  2019-05-06 08:57:56  51.80  4018025271936
# ...               ...                  ...    ...            ...
# 2370      Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371  Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372      North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373     West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374       Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 2250             9  Rural
# 2251             8  Rural
# 2252             6  Rural
# 2253             2  Rural
# 2254             2  Rural
# ...

# %%
urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
urban_ride_count
# Out:
# city
# Amandaburgh            18
# Barajasview            22
# Carriemouth            27
# Christopherfurt        27
# Deanville              19
#                        ..
# West Patrickchester    16
# West Robert            31
# West Samuelburgh       25
# Williamsstad           23
# Williamsview           20
# Name: ride_id, Length: 66, dtype: int64

# %%
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]
suburban_ride_count
# Out:
# city
# Barronchester         16
# Bethanyland           18
# Brandonfort           19
# Colemanland           22
# Davidfurt             17
# East Aaronbury         9
# East Danielview       17
# East Kentstad         13
# East Marymouth        27
# Grayville             15
# Josephside            27
# Lake Ann              12
# Lake Omar             14
# Lake Robertside       25
# Lake Scott            18
# Lewishaven            12
# Lewisland             17
# Mezachester           17
# Myersshire            16
# New Olivia            17
# New Raymond           22
# New Shannonberg       17
# Nicolechester         19
# North Jeffrey         13
# North Richardhaven    14
# North Timothy         15
# Port Shane            19
# Rodriguezview         15
# Sotoville             11
# South Brenda          24
# South Teresa          22
# Veronicaberg          17
# Victoriaport          14
# West Hannah           21
# West Kimmouth         20
# Williamsonville       14
# ...

# %%
rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]
rural_ride_count
# Out:
# city
# Bradshawfurt         10
# Garzaport             3
# Harringtonfort        6
# Jessicaport           6
# Lake Jamie            6
# Lake Latoyabury      11
# Michaelberg          12
# New Ryantown          6
# Newtonview            4
# North Holly           9
# North Jaime           8
# Penaborough           5
# Randallchester        5
# South Jennifer        7
# South Marychester     8
# South Saramouth       4
# Taylorhaven           6
# West Heather          9
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
drivers_by_city = pyber_data_df.groupby(["type"]).sum()['driver_count']

# %%
urban_driver_count = urban_cities_df.groupby(["type"]).sum()["driver_count"]
urban_driver_count
# Out:
# type
# Urban    59602
# Name: driver_count, dtype: int64

# %%
suburban_driver_count = suburban_cities_df.groupby(["type"]).sum()["driver_count"]
suburban_driver_count
# Out:
# type
# Suburban    8570
# Name: driver_count, dtype: int64

# %%
rural_driver_count = rural_cities_df.groupby(["type"]).sum()["driver_count"]
rural_driver_count
# Out:
# type
# Rural    537
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fare_by_type = pyber_data_df.groupby(["type"]).sum()['fare']

# %%
urban_fare = urban_cities_df.groupby(["type"]).sum()["fare"]
urban_fare
# Out:
# type
# Urban    39854.38
# Name: fare, dtype: float64

# %%
suburban_fare = suburban_cities_df.groupby(["type"]).sum()["fare"]
suburban_fare
# Out:
# type
# Suburban    19356.33
# Name: fare, dtype: float64

# %%
rural_fare = rural_cities_df.groupby(["type"]).sum()["fare"]
rural_fare
# Out:
# type
# Rural    4327.93
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 

avg_far_per_ride =  (total_fare_by_type)/ (total_rides_by_type)
avg_far_per_ride
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
urban_avg_fare
# Out:
# city
# Amandaburgh            24.641667
# Barajasview            25.332273
# Carriemouth            28.314444
# Christopherfurt        24.501852
# Deanville              25.842632
#                          ...
# West Patrickchester    28.233125
# West Robert            25.123871
# West Samuelburgh       21.767600
# Williamsstad           24.362174
# Williamsview           26.599000
# Name: fare, Length: 66, dtype: float64

# %%
suburban_avg_fare = suburban_cities_df.groupby(["city"]).mean()["fare"]
suburban_avg_fare
# Out:
# city
# Barronchester         36.422500
# Bethanyland           32.956111
# Brandonfort           35.437368
# Colemanland           30.894545
# Davidfurt             31.995882
# East Aaronbury        25.661111
# East Danielview       31.560588
# East Kentstad         29.823077
# East Marymouth        30.835185
# Grayville             27.763333
# Josephside            32.858148
# Lake Ann              30.890000
# Lake Omar             28.075000
# Lake Robertside       31.262000
# Lake Scott            31.886111
# Lewishaven            25.241667
# Lewisland             34.614118
# Mezachester           30.760000
# Myersshire            30.203125
# New Olivia            34.054118
# New Raymond           27.961818
# New Shannonberg       28.378235
# Nicolechester         30.909474
# North Jeffrey         29.242308
# North Richardhaven    24.704286
# North Timothy         31.262000
# Port Shane            31.077895
# Rodriguezview         30.745333
# Sotoville             31.980000
# ...

# %%
rural_avg_fare = rural_cities_df.groupby(["city"]).mean()["fare"]
rural_avg_fare
# Out:
# city
# Bradshawfurt         40.064000
# Garzaport            24.123333
# Harringtonfort       33.470000
# Jessicaport          36.013333
# Lake Jamie           34.358333
# Lake Latoyabury      26.061818
# Michaelberg          34.997500
# New Ryantown         43.278333
# Newtonview           36.745000
# North Holly          29.130000
# North Jaime          30.802500
# Penaborough          35.246000
# Randallchester       29.742000
# South Jennifer       35.264286
# South Marychester    41.870000
# South Saramouth      36.160000
# Taylorhaven          42.263333
# West Heather         33.890000
# Name: fare, dtype: float64

# %%
#5. Get the average fare per driver for each city type. 

avg_far_per_ride =  (total_fare_by_type)/ (total_rides_by_type)
avg_fare_driver_per_ride =  (total_fare_by_type)/ (total_driver_by_type)

# %%
total_driver_by_type
# Out:
# type
# Rural         537
# Suburban     8570
# Urban       59602
# Name: driver_count, dtype: int64

# %%
avg_fare_for_urban_driver = urban_fare / urban_ride_count.count()
avg_fare_for_urban_driver
# Out:
# type
# Urban    603.854242
# Name: fare, dtype: float64

# %%
avg_fare_for_suburban_driver = suburban_fare / suburban_ride_count.count()
avg_fare_for_suburban_driver
# Out:
# type
# Suburban    537.675833
# Name: fare, dtype: float64

# %%
avg_fare_for_rural_driver = rural_fare / rural_ride_count.count()
avg_fare_for_rural_driver
# Out:
# type
# Rural    240.440556
# Name: fare, dtype: float64

# %%
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
ride_data_df
# Out:
#                     city                 date   fare        ride_id
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
# [2375 rows x 4 columns]

# %%
city_data_df
# Out:
#                 city  driver_count   type
# 0        Richardfort            38  Urban
# 1       Williamsstad            59  Urban
# 2        Port Angela            67  Urban
# 3         Rodneyfort            34  Urban
# 4        West Robert            39  Urban
# ..               ...           ...    ...
# 115     Bradshawfurt             7  Rural
# 116     New Ryantown             2  Rural
# 117   Randallchester             9  Rural
# 118      Jessicaport             1  Rural
# 119  South Saramouth             7  Rural
#
# [120 rows x 3 columns]

# %%
per_type_total_drivers = city_data_df.groupby(["type"]).sum()["driver_count"]

# %%
avg_far_per_ride =  (total_fare_by_type)/ (total_rides_by_type)
avg_fare_driver_per_ride =  (total_fare_by_type)/ (per_type_total_drivers)

# %%
#  6. Create a PyBer summary DataFrame. 
#!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
per_pyber_types = pyber_data_df.set_index(["type"])
per_pyber_types_counts = pyber_data_df["type"].value_counts()


per_type_total_rides = pyber_data_df.groupby(["type"]).count()["ride_id"]


per_type_total_drivers = city_data_df.groupby(["type"]).sum()["driver_count"]

per_type_total_fares = pyber_data_df.groupby(["type"]).sum()["fare"]


per_avg_fare_per_ride = per_type_total_fares / per_type_total_rides
per_avg_fare_per_driver = per_type_total_fares / per_type_total_drivers

pyber_summary_df= pd.DataFrame({"Total Rides" : per_type_total_rides,
                   "Total Drivers": per_type_total_drivers,
                   "Total Fares": per_type_total_fares,
                   "Average Fare per Ride": avg_far_per_ride, 
                   "Average Fare per Driver": avg_fare_driver_per_ride})
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
avg_fare_driver_per_ride
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
 per_type_total_fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
per_type_total_rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
per_type_total_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.
pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
type_date_fare_sum_dataframe = pyber_data_df.groupby(["type", "date"]).sum()[["fare"]]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
type_date_fare_sum_dataframe= pyber_data_df.reset_index()

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
type_date_fare_sum_dataframe_pivot= pyber_data_df.pivot(index = "date", columns = "type", values = "fare")

# %%
type_date_fare_sum_dataframe_pivot
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
jan_to_april_fare = type_date_fare_sum_dataframe_pivot.loc['2019-01-01':'2019-04-29']

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
type_date_fare_sum_dataframe_pivot.index = pd.to_datetime(type_date_fare_sum_dataframe_pivot.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
type_date_fare_sum_dataframe_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2375 entries, 2019-01-01 00:08:16 to 2019-05-08 13:10:18
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     125 non-null    float64
#  1   Suburban  625 non-null    float64
#  2   Urban     1625 non-null   float64
# dtypes: float64(3)
# memory usage: 74.2 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
type_fare_by_week = type_date_fare_sum_dataframe_pivot.resample("W").sum()

# %%
type_fare_by_week
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29
# 2019-05-05  257.42   1164.78  2178.57
# 2019-05-12  156.82    308.21   610.03

# %%
type_fare_by_week
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29
# 2019-05-05  257.42   1164.78  2178.57
# 2019-05-12  156.82    308.21   610.03

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 
# %matplotlib inline
import matplotlib.pyplot as plt
# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.


plt.style.use('fivethirtyeight')
weekly_fare= type_fare_by_week.plot(figsize= (24,7), label="type")
weekly_fare.set_xlabel("2019")
weekly_fare.set_ylabel("Fare($USD)")
plt.ylim(0,2501)
plt.title('Total Fare by City Type')
plt.legend()
plt.savefig("analysis/PyBer_fare_summary.png")
